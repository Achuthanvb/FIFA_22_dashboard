# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\Football_players_2021_2022\\New data\\players_data\\players_22.csv')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14660\253327454.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\Football_players_2021_2022\\New data\\players_data\\players_22.csv')

# %%
df1.shape
# Out:
# (19239, 110)

# %%
for i in df1.columns:
    print(i)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# player_positions
# overall
# potential
# value_eur
# wage_eur
# age
# dob
# height_cm
# weight_kg
# club_team_id
# club_name
# league_name
# league_level
# club_position
# club_jersey_number
# club_loaned_from
# club_joined
# club_contract_valid_until
# nationality_id
# nationality_name
# nation_team_id
# nation_position
# nation_jersey_number
# preferred_foot
# weak_foot
# skill_moves
# international_reputation
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# player_traits
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
df1.league_name.unique()
# Out:
# array(['French Ligue 1', 'German 1. Bundesliga', 'English Premier League',
#        'Spain Primera Division', 'Italian Serie A', 'Holland Eredivisie',
#        'USA Major League Soccer', nan, 'Saudi Abdul L. Jameel League',
#        'Portuguese Liga ZON SAGRES', 'Campeonato Brasileiro Série A',
#        'Turkish Süper Lig', 'Chinese Super League',
#        'Russian Premier League', 'Croatian Prva HNL', 'Mexican Liga MX',
#        'Ukrainian Premier League', 'Spanish Segunda División',
#        'Greek Super League', 'Italian Serie B',
#        'Belgian Jupiler Pro League', 'Argentina Primera División',
#        'German 2. Bundesliga', 'Japanese J. League Division 1',
#        'Swiss Super League', 'Czech Republic Gambrinus Liga',
#        'Scottish Premiership', 'English League Championship',
#        'French Ligue 2', 'Australian Hyundai A-League',
#        'Danish Superliga', 'Chilian Campeonato Nacional',
#        'Austrian Football Bundesliga', 'Paraguayan Primera División',
# ...

# %%
options = ['French Ligue 1', 'German 1. Bundesliga', 'English Premier League',
       'Spain Primera Division', 'Italian Serie A','Indian Super League' ]
  
# selecting rows based on condition
df3 = df1[df1['league_name'].isin(options)]

# %%
df3.shape
# Out:
# (3255, 110)

# %%
for i in df3.columns:
    print(i,'--',df3[i].isnull().sum())
# Out:
# sofifa_id -- 0
# player_url -- 0
# short_name -- 0
# long_name -- 0
# player_positions -- 0
# overall -- 0
# potential -- 0
# value_eur -- 0
# wage_eur -- 0
# age -- 0
# dob -- 0
# height_cm -- 0
# weight_kg -- 0
# club_team_id -- 0
# club_name -- 0
# league_name -- 0
# league_level -- 0
# club_position -- 0
# club_jersey_number -- 0
# club_loaned_from -- 3035
# club_joined -- 220
# club_contract_valid_until -- 0
# nationality_id -- 0
# nationality_name -- 0
# nation_team_id -- 2906
# nation_position -- 2906
# nation_jersey_number -- 2906
# preferred_foot -- 0
# weak_foot -- 0
# skill_moves -- 0
# international_reputation -- 0
# work_rate -- 0
# body_type -- 0
# real_face -- 0
# release_clause_eur -- 220
# player_tags -- 2811
# player_traits -- 1239
# pace -- 358
# shooting -- 358
# passing -- 358
# dribbling -- 358
# defending -- 358
# physic -- 358
# attacking_crossing -- 0
# attacking_finishing -- 0
# attacking_heading_accuracy -- 0
# attacking_short_passing -- 0
# ...

# %%
df3.drop(columns=['club_loaned_from','club_joined','nationality_id','nation_team_id','nation_position','nation_jersey_number',
                 'release_clause_eur','player_tags','player_traits','nation_logo_url'],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14660\733596355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(columns=['club_loaned_from','club_joined','nationality_id','nation_team_id','nation_position','nation_jersey_number',

# %%
for i in df3.columns:
    print(i,'--',df3[i].isnull().sum())
# Out:
# sofifa_id -- 0
# player_url -- 0
# short_name -- 0
# long_name -- 0
# player_positions -- 0
# overall -- 0
# potential -- 0
# value_eur -- 0
# wage_eur -- 0
# age -- 0
# dob -- 0
# height_cm -- 0
# weight_kg -- 0
# club_team_id -- 0
# club_name -- 0
# league_name -- 0
# league_level -- 0
# club_position -- 0
# club_jersey_number -- 0
# club_contract_valid_until -- 0
# nationality_name -- 0
# preferred_foot -- 0
# weak_foot -- 0
# skill_moves -- 0
# international_reputation -- 0
# work_rate -- 0
# body_type -- 0
# real_face -- 0
# pace -- 358
# shooting -- 358
# passing -- 358
# dribbling -- 358
# defending -- 358
# physic -- 358
# attacking_crossing -- 0
# attacking_finishing -- 0
# attacking_heading_accuracy -- 0
# attacking_short_passing -- 0
# attacking_volleys -- 0
# skill_dribbling -- 0
# skill_curve -- 0
# skill_fk_accuracy -- 0
# skill_long_passing -- 0
# skill_ball_control -- 0
# movement_acceleration -- 0
# movement_sprint_speed -- 0
# movement_agility -- 0
# ...

# %%
df_main1=df3[df3['player_positions']!='GK']

# %%
df_gk1=df3[df3['player_positions']=='GK']

# %%
#df_main1.to_csv('C:\\Users\\Lenovo\\Desktop\\Football_players_2021_2022\\New data\\transformed players\\main_players.csv')
#df_gk1.to_csv('C:\\Users\\Lenovo\\Desktop\\Football_players_2021_2022\\New data\\transformed players\\goalkeepers.csv')

# %%
df_main1.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age', 'dob', 'height_cm', 'weight_kg', 'club_team_id', 'club_name',
#        'league_name', 'league_level', 'club_position', 'club_jersey_number',
#        'club_contract_valid_until', 'nationality_name', 'preferred_foot',
#        'weak_foot', 'skill_moves', 'international_reputation', 'work_rate',
#        'body_type', 'real_face', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
# ...

# %%
for i in df_gk1.columns:
    print(i,'--',df_gk1[i].isnull().sum())
# Out:
# sofifa_id -- 0
# player_url -- 0
# short_name -- 0
# long_name -- 0
# player_positions -- 0
# overall -- 0
# potential -- 0
# value_eur -- 0
# wage_eur -- 0
# age -- 0
# dob -- 0
# height_cm -- 0
# weight_kg -- 0
# club_team_id -- 0
# club_name -- 0
# league_name -- 0
# league_level -- 0
# club_position -- 0
# club_jersey_number -- 0
# club_contract_valid_until -- 0
# nationality_name -- 0
# preferred_foot -- 0
# weak_foot -- 0
# skill_moves -- 0
# international_reputation -- 0
# work_rate -- 0
# body_type -- 0
# real_face -- 0
# pace -- 358
# shooting -- 358
# passing -- 358
# dribbling -- 358
# defending -- 358
# physic -- 358
# attacking_crossing -- 0
# attacking_finishing -- 0
# attacking_heading_accuracy -- 0
# attacking_short_passing -- 0
# attacking_volleys -- 0
# skill_dribbling -- 0
# skill_curve -- 0
# skill_fk_accuracy -- 0
# skill_long_passing -- 0
# skill_ball_control -- 0
# movement_acceleration -- 0
# movement_sprint_speed -- 0
# movement_agility -- 0
# ...

# %%
df_main1.loc[:,'sofifa_id':'weight_kg']
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19200     261549  https://sofifa.com/player/261549/balaji-ganesa...
# 19226     259219  https://sofifa.com/player/259219/nestor-dias/2...
# 19228     259650  https://sofifa.com/player/259650/fardin-ali-mo...
# 19229     259737  https://sofifa.com/player/259737/haobam-singh/...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
df_main1.loc[:,'club_team_id':'body_type']
# Out:
#        club_team_id            club_name             league_name  \
# 0              73.0  Paris Saint-Germain          French Ligue 1
# 1              21.0    FC Bayern München    German 1. Bundesliga
# 2              11.0    Manchester United  English Premier League
# 3              73.0  Paris Saint-Germain          French Ligue 1
# 4              10.0      Manchester City  English Premier League
# ...             ...                  ...                     ...
# 19200      113297.0        Chennaiyin FC     Indian Super League
# 19226      113298.0               FC Goa     Indian Super League
# 19228      113146.0   ATK Mohun Bagan FC     Indian Super League
# 19229      111629.0    SC East Bengal FC     Indian Super League
# 19238      113040.0  NorthEast United FC     Indian Super League
#
#        league_level club_position  club_jersey_number  \
# 0               1.0            RW                30.0
# 1               1.0            ST                 9.0
# ...

# %%
,''

# %%
df_main1[['attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_short_passing',
       'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control']]
# Out:
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                      85                   95                          70
# 1                      71                   95                          90
# 2                      87                   95                          90
# 3                      85                   83                          63
# 4                      94                   82                          55
# ...                   ...                  ...                         ...
# 19200                  43                   25                          43
# 19226                  36                   38                          43
# 19228                  29                   50                          34
# 19229                  36                   34                          48
# 19238                  39                   32                          46
#
# ...

# %%
df_main1[['movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots']]
# Out:
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                         91                     80                91
# 1                         77                     79                77
# 2                         85                     88                86
# 3                         93                     89                96
# 4                         76                     76                79
# ...                      ...                    ...               ...
# 19200                     64                     59                57
# 19226                     57                     57                59
# 19228                     68                     51                59
# 19229                     62                     63                69
# 19238                     70                     67                65
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# ...

# %%
df_main1[['mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle']]
# Out:
#        mentality_aggression  mentality_interceptions  mentality_positioning  \
# 0                        44                       40                     93
# 1                        81                       49                     95
# 2                        63                       29                     95
# 3                        63                       37                     86
# 4                        76                       66                     88
# ...                     ...                      ...                    ...
# 19200                    46                       43                     42
# 19226                    57                       40                     45
# 19228                    32                       16                     52
# 19229                    57                       45                     49
# 19238                    55                       42                     47
#
# ...

# %%
df_main1.drop(columns=['club_team_id','league_level','weak_foot',],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14660\2353138420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main1.drop(columns=['club_team_id','league_level','weak_foot',],inplace=True)

# %%
df_main1[['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
       'lm', 'lcm', 'cm', 'rcm']].head(2)
# Out:
#      ls    st    rs  lw  lf  cf  rf  rw   lam   cam   ram    lm   lcm    cm  \
# 0  89+3  89+3  89+3  92  93  93  93  92    93    93    93  91+2  87+3  87+3
# 1  90+2  90+2  90+2  85  88  88  88  85  86+3  86+3  86+3  84+3  80+3  80+3
#
#     rcm
# 0  87+3
# 1  80+3

# %%
df_main1[[ 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
       'lcb', 'cb', 'rcb', 'rb', 'gk']].head(2)
# Out:
#      rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk
# 0  91+2  66+3  64+3  64+3  64+3  66+3  61+3  50+3  50+3  50+3  61+3  19+3
# 1  84+3  64+3  66+3  66+3  66+3  64+3  61+3  60+3  60+3  60+3  61+3  19+3

# %%
df_main1['lb_rb']=df_main1.lb
df_main1['lm_rm']=df_main1.lm
df_main1['lw_rw']=df_main1.lw
df_main1['wing_back']=df_main1.rwb


df_main1.drop(columns=['rcb','lcb','rwb','lwb','ldm','rdm','lcm','rcm','lm','rm','ram','lam','ls','rs','lw','rw','lf','rf'],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14660\1593387285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main1['lb_rb']=df_main1.lb
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14660\1593387285.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main1['lm_rm']=df_main1.lm
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14660\1593387285.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_main1.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age', 'dob', 'height_cm', 'weight_kg', 'club_team_id', 'club_name',
#        'league_name', 'league_level', 'club_position', 'club_jersey_number',
#        'club_contract_valid_until', 'nationality_name', 'preferred_foot',
#        'weak_foot', 'skill_moves', 'international_reputation', 'work_rate',
#        'body_type', 'real_face', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
# ...

# %%
df_main1[['st', 'cf', 'cam', 'cm', 'cdm', 'lb', 'cb', 'rb', 'gk','lb_rb', 'lm_rm', 'lw_rw', 'wing_back']]
# Out:
#          st  cf   cam    cm   cdm    lb    cb    rb    gk lb_rb lm_rm lw_rw  \
# 0      89+3  93    93  87+3  64+3  61+3  50+3  61+3  19+3  61+3  91+2    92
# 1      90+2  88  86+3  80+3  66+3  61+3  60+3  61+3  19+3  61+3  84+3    85
# 2      90+1  89  86+3  78+3  59+3  60+3  53+3  60+3  20+3  60+3  86+3    88
# 3      83+3  88  89+2  82+3  63+3  62+3  50+3  62+3  20+3  62+3  89+2    90
# 4      83+3  87  89+2  89+2  80+3  75+3  69+3  75+3  21+3  75+3  89+2    88
# ...     ...  ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 19200  37+2  39  38+2  38+2  40+2  46+2  43+2  46+2  13+2  46+2  43+2    41
# 19226  45+2  47  48+2  47+2  46+2  45+2  44+2  45+2  14+2  45+2  48+2    47
# 19228  46+2  47  46+2  39+2  29+2  29+2  26+2  29+2  13+2  29+2  44+2    46
# 19229  45+2  46  47+2  47+2  46+2  47+2  45+2  47+2  16+2  47+2  47+2    47
# 19238  45+2  47  47+2  46+2  44+2  45+2  41+2  45+2  16+2  45+2  48+2    47
#
#       wing_back
# 0          66+3
# 1          64+3
# ...

# %%
df_main1.drop(columns=['lb','rb'],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14660\1728216822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main1.drop(columns=['lb','rb'],inplace=True)

# %%
df_main1.reset_index(inplace=True)

# %%
df_main1[['st', 'cf', 'cam', 'cm', 'cdm',  'cb', 'gk','lb_rb', 'lm_rm', 'lw_rw', 'wing_back']]
# Out:
#          st  cf   cam    cm   cdm    cb    gk lb_rb lm_rm lw_rw wing_back
# 0      89+3  93    93  87+3  64+3  50+3  19+3  61+3  91+2    92      66+3
# 1      90+2  88  86+3  80+3  66+3  60+3  19+3  61+3  84+3    85      64+3
# 2      90+1  89  86+3  78+3  59+3  53+3  20+3  60+3  86+3    88      63+3
# 3      83+3  88  89+2  82+3  63+3  50+3  20+3  62+3  89+2    90      67+3
# 4      83+3  87  89+2  89+2  80+3  69+3  21+3  75+3  89+2    88      79+3
# ...     ...  ..   ...   ...   ...   ...   ...   ...   ...   ...       ...
# 19200  37+2  39  38+2  38+2  40+2  43+2  13+2  46+2  43+2    41      46+2
# 19226  45+2  47  48+2  47+2  46+2  44+2  14+2  45+2  48+2    47      45+2
# 19228  46+2  47  46+2  39+2  29+2  26+2  13+2  29+2  44+2    46      31+2
# 19229  45+2  46  47+2  47+2  46+2  45+2  16+2  47+2  47+2    47      47+2
# 19238  45+2  47  47+2  46+2  44+2  41+2  16+2  45+2  48+2    47      45+2
#
# [2897 rows x 11 columns]

# %%
list1=['st', 'cf', 'cam', 'cm', 'cdm',  'cb', 'gk','lb_rb', 'lm_rm', 'lw_rw', 'wing_back']
for i in list1:
    for j in range(len(df_main1)):
        df_main1.loc[j,i]=eval(str(df_main1.loc[j,i]))

# %%
df_main1[['st', 'cf', 'cam', 'cm', 'cdm',  'cb', 'gk','lb_rb', 'lm_rm', 'lw_rw', 'wing_back']]
# Out:
#       st  cf cam  cm cdm  cb  gk lb_rb lm_rm lw_rw wing_back
# 0     92  93  93  90  67  53  22    64    93    92        69
# 1     92  88  89  83  69  63  22    64    87    85        67
# 2     91  89  89  81  62  56  23    63    89    88        66
# 3     86  88  91  85  66  53  23    65    91    90        70
# 4     86  87  91  91  83  72  24    78    91    88        82
# ...   ..  ..  ..  ..  ..  ..  ..   ...   ...   ...       ...
# 2892  39  39  40  40  42  45  15    48    45    41        48
# 2893  47  47  50  49  48  46  16    47    50    47        47
# 2894  48  47  48  41  31  28  15    31    46    46        33
# 2895  47  46  49  49  48  47  18    49    49    47        49
# 2896  47  47  49  48  46  43  18    47    50    47        47
#
# [2897 rows x 11 columns]

# %%
df_main1.st[:10]
# Out:
# 0       92
# 1       92
# 2       91
# 3       86
# 4       86
# 6     89+3
# 9     88+2
# 10    72+3
# 11    87+2
# 13    85+3
# Name: st, dtype: object

# %%
df_main1.to_csv('C:\\Users\\Lenovo\\Desktop\\Football_players_2021_2022\\New data\\transformed players\\main_players1.csv')
df_gk1.to_csv('C:\\Users\\Lenovo\\Desktop\\Football_players_2021_2022\\New data\\transformed players\\goalkeepers1.csv')
